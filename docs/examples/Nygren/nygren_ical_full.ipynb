# %%
import os, tempfile
import logging
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from ionchannelABC import theoretical_population_size
from ionchannelABC import IonChannelDistance, EfficientMultivariateNormalTransition, IonChannelAcceptor
from ionchannelABC import plot_sim_results, plot_parameters_kde
from ionchannelABC.experiment import setup
# Out:
# INFO:myokit:Loading Myokit version 1.28.3
# /scratch/cph211/miniconda3/envs/ionchannelABC/lib/python3.7/site-packages/ionchannelABC-0.2.0-py3.7.egg/ionchannelABC/visualization.py:289: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# /scratch/cph211/miniconda3/envs/ionchannelABC/lib/python3.7/site-packages/ionchannelABC-0.2.0-py3.7.egg/ionchannelABC/visualization.py:303: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# /scratch/cph211/miniconda3/envs/ionchannelABC/lib/python3.7/site-packages/ionchannelABC-0.2.0-py3.7.egg/ionchannelABC/visualization.py:289: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# /scratch/cph211/miniconda3/envs/ionchannelABC/lib/python3.7/site-packages/ionchannelABC-0.2.0-py3.7.egg/ionchannelABC/visualization.py:303: SyntaxWarning: assertion is always true, perhaps remove parentheses?

# %%
from pyabc import Distribution, RV, History, ABCSMC
from pyabc.epsilon import MedianEpsilon
from pyabc.sampler import MulticoreEvalParallelSampler, SingleCoreSampler
from pyabc.populationstrategy import ConstantPopulationSize

# %%
from experiments.ical_li import (li_act_and_tau,
                                 li_inact_1000,
                                 li_inact_kin_80,
                                 li_recov)

# %%
modelfile = 'models/nygren_ical.mmt'

# %% [markdown]
# ## Plot steady-state and tau functions

# %%
from ionchannelABC.visualization import plot_variables

# %%
sns.set_context('talk')

V = np.arange(-140, 50, 0.01)

nyg_vars = {'di': 'ical.d_inf',
            'f1i': 'ical.f_inf',
            'f2i': 'ical.f_inf',
            'dt': 'ical.tau_d',
            'f1t': 'ical.tau_f_1',
            'f2t': 'ical.tau_f_2'}

f, ax = plot_variables(V, nyg_vars, 'models/nygren_ical.mmt', figshape=(3,2))

# %% [markdown]
# # d gate -> Only activation data

# %%
observations, model, summary_statistics = setup(modelfile,
                                                li_act_and_tau)

# %%
assert len(observations)==len(summary_statistics(model({})))

# %%
g = plot_sim_results(modelfile,
                     li_act_and_tau)

# %%
limits = {'ical.p1': (-100, 100),
          'ical.p2': (0, 50),
          'log_ical.p3': (-7, 3),
          'ical.p4': (-100, 100),
          'ical.p5': (0, 50),
          'log_ical.p6': (-7, 3)}
prior = Distribution(**{key: RV("uniform", a, b - a)
                        for key, (a,b) in limits.items()})

# %% [markdown]
# ### Run ABC calibration

# %%
db_path = ("sqlite:///" +
            os.path.join(tempfile.gettempdir(), "nygren_ical_dgate_full.db"))

# %%
logging.basicConfig()
abc_logger = logging.getLogger('ABC')
abc_logger.setLevel(logging.DEBUG)
eps_logger = logging.getLogger('Epsilon')
eps_logger.setLevel(logging.DEBUG)

# %%
pop_size = theoretical_population_size(2, len(limits))
print("Theoretical minimum population size is {} particles".format(pop_size))
# Out:
# Theoretical minimum population size is 64 particles

# %%
abc = ABCSMC(models=model,
             parameter_priors=prior,
             distance_function=IonChannelDistance(
                 exp_id=list(observations.exp_id),
                 variance=list(observations.variance),
                 delta=0.05),
             population_size=ConstantPopulationSize(2000),
             summary_statistics=summary_statistics,
             transitions=EfficientMultivariateNormalTransition(),
             eps=MedianEpsilon(initial_epsilon=100),
             sampler=MulticoreEvalParallelSampler(n_procs=16),
             acceptor=IonChannelAcceptor())
# Out:
# DEBUG:ABC:ion channel weights: {'0': 1.2287454676498424, '1': 1.2287454676498424, '2': 1.2287454676498424, '3': 1.2287454676498424, '4': 1.2287454676498424, '5': 1.2287454676498424, '6': 1.2287454676498424, '7': 1.0293830767146164, '8': 0.6283247351374927, '9': 0.5133263088125923, '10': 0.4040167399213943, '11': 0.41888315675832816, '12': 0.5146915383573082, '13': 1.2287454676498424, '14': 1.2287454676498424, '15': 1.2287454676498424, '16': 1.2039197677998432}
# DEBUG:Epsilon:init quantile_epsilon initial_epsilon=100, quantile_multiplier=1

# %%
obs = observations.to_dict()['y']
obs = {str(k): v for k, v in obs.items()}

# %%
abc_id = abc.new(db_path, obs)
# Out:
# INFO:History:Start <ABCSMC(id=1, start_time=2019-10-18 09:52:37.719386, end_time=None)>

# %%
history = abc.run(minimum_epsilon=0., max_nr_populations=100, min_acceptance_rate=0.01)
# Out:
# INFO:ABC:t:0 eps:100
# DEBUG:ABC:now submitting population 0
# DEBUG:ABC:population 0 done
# DEBUG:ABC:
# total nr simulations up to t =0 is 3852
# DEBUG:Epsilon:new eps, t=1, eps=2.551139210627562
# INFO:ABC:t:1 eps:2.551139210627562
# DEBUG:ABC:now submitting population 1
# DEBUG:ABC:population 1 done
# DEBUG:ABC:
# total nr simulations up to t =1 is 8011
# DEBUG:Epsilon:new eps, t=2, eps=1.5010936714315752
# INFO:ABC:t:2 eps:1.5010936714315752
# DEBUG:ABC:now submitting population 2
# DEBUG:ABC:population 2 done
# DEBUG:ABC:
# total nr simulations up to t =2 is 12588
# DEBUG:Epsilon:new eps, t=3, eps=1.2691794246600032
# INFO:ABC:t:3 eps:1.2691794246600032
# DEBUG:ABC:now submitting population 3
# DEBUG:ABC:population 3 done
# DEBUG:ABC:
# total nr simulations up to t =3 is 17866
# DEBUG:Epsilon:new eps, t=4, eps=1.0801458314591663
# INFO:ABC:t:4 eps:1.0801458314591663
# DEBUG:ABC:now submitting population 4
# DEBUG:ABC:population 4 done
# DEBUG:ABC:
# total nr simulations up to t =4 is 24716
# DEBUG:Epsilon:new eps, t=5, eps=0.8539519930070646
# INFO:ABC:t:5 eps:0.8539519930070646
# DEBUG:ABC:now submitting population 5
# DEBUG:ABC:population 5 done
# DEBUG:ABC:
# total nr simulations up to t =5 is 34352
# DEBUG:Epsilon:new eps, t=6, eps=0.6978616385054854
# INFO:ABC:t:6 eps:0.6978616385054854
# DEBUG:ABC:now submitting population 6
# DEBUG:ABC:population 6 done
# DEBUG:ABC:
# total nr simulations up to t =6 is 46462
# DEBUG:Epsilon:new eps, t=7, eps=0.5940892545047777
# INFO:ABC:t:7 eps:0.5940892545047777
# DEBUG:ABC:now submitting population 7
# DEBUG:ABC:population 7 done
# DEBUG:ABC:
# total nr simulations up to t =7 is 62801
# DEBUG:Epsilon:new eps, t=8, eps=0.5247404510611778
# INFO:ABC:t:8 eps:0.5247404510611778
# DEBUG:ABC:now submitting population 8
# DEBUG:ABC:population 8 done
# DEBUG:ABC:
# total nr simulations up to t =8 is 88963
# DEBUG:Epsilon:new eps, t=9, eps=0.45558639136253815
# INFO:ABC:t:9 eps:0.45558639136253815
# DEBUG:ABC:now submitting population 9
# DEBUG:ABC:population 9 done
# DEBUG:ABC:
# total nr simulations up to t =9 is 118042
# DEBUG:Epsilon:new eps, t=10, eps=0.38120196698193115
# INFO:ABC:t:10 eps:0.38120196698193115
# DEBUG:ABC:now submitting population 10
# DEBUG:ABC:population 10 done
# DEBUG:ABC:
# total nr simulations up to t =10 is 166911
# DEBUG:Epsilon:new eps, t=11, eps=0.3193304899197226
# INFO:ABC:t:11 eps:0.3193304899197226
# DEBUG:ABC:now submitting population 11
# DEBUG:ABC:population 11 done
# DEBUG:ABC:
# total nr simulations up to t =11 is 219030
# DEBUG:Epsilon:new eps, t=12, eps=0.26274204523124334
# INFO:ABC:t:12 eps:0.26274204523124334
# DEBUG:ABC:now submitting population 12
# DEBUG:ABC:population 12 done
# DEBUG:ABC:
# total nr simulations up to t =12 is 274211
# DEBUG:Epsilon:new eps, t=13, eps=0.21604097484113563
# INFO:ABC:t:13 eps:0.21604097484113563
# DEBUG:ABC:now submitting population 13
# DEBUG:ABC:population 13 done
# DEBUG:ABC:
# total nr simulations up to t =13 is 331461
# DEBUG:Epsilon:new eps, t=14, eps=0.177731737579979
# INFO:ABC:t:14 eps:0.177731737579979
# DEBUG:ABC:now submitting population 14
# DEBUG:ABC:population 14 done
# DEBUG:ABC:
# total nr simulations up to t =14 is 400733
# DEBUG:Epsilon:new eps, t=15, eps=0.145120044771897
# INFO:ABC:t:15 eps:0.145120044771897
# DEBUG:ABC:now submitting population 15
# DEBUG:ABC:population 15 done
# DEBUG:ABC:
# total nr simulations up to t =15 is 453655
# DEBUG:Epsilon:new eps, t=16, eps=0.12043147489192634
# INFO:ABC:t:16 eps:0.12043147489192634
# DEBUG:ABC:now submitting population 16
# DEBUG:ABC:population 16 done
# DEBUG:ABC:
# total nr simulations up to t =16 is 531377
# DEBUG:Epsilon:new eps, t=17, eps=0.10120781607656772
# INFO:ABC:t:17 eps:0.10120781607656772
# DEBUG:ABC:now submitting population 17
# DEBUG:ABC:population 17 done
# DEBUG:ABC:
# total nr simulations up to t =17 is 621495
# DEBUG:Epsilon:new eps, t=18, eps=0.08679001119768372
# INFO:ABC:t:18 eps:0.08679001119768372
# DEBUG:ABC:now submitting population 18
# DEBUG:ABC:population 18 done
# DEBUG:ABC:
# total nr simulations up to t =18 is 719164
# DEBUG:Epsilon:new eps, t=19, eps=0.07456337211984806
# INFO:ABC:t:19 eps:0.07456337211984806
# DEBUG:ABC:now submitting population 19
# DEBUG:ABC:population 19 done
# DEBUG:ABC:
# total nr simulations up to t =19 is 846201
# DEBUG:Epsilon:new eps, t=20, eps=0.06578136385333222
# INFO:ABC:t:20 eps:0.06578136385333222
# DEBUG:ABC:now submitting population 20
# DEBUG:ABC:population 20 done
# DEBUG:ABC:
# total nr simulations up to t =20 is 1176639
# DEBUG:Epsilon:new eps, t=21, eps=0.05927034322201104
# INFO:History:Done <ABCSMC(id=1, start_time=2019-10-18 09:52:37.719386, end_time=2019-10-18 11:12:07.102511)>

# %% [markdown]
# ### Database results analysis

# %%
history = History(db_path)

# %%
df, w = history.get_distribution(m=0)

# %%
g = plot_sim_results(modelfile,
                     li_act_and_tau,
                     df=df, w=w)

# %%
nyg_pars = df.sample(n=100, weights=w, replace=True)
nyg_pars = nyg_pars.set_index([pd.Index(range(100))])
nyg_pars = nyg_pars.to_dict(orient='records')

# %%
sns.set_context('talk')
mpl.rcParams['font.size'] = 14
mpl.rcParams['legend.fontsize'] = 14

f, ax = plot_variables(V, nyg_vars, 
                       'models/nygren_ical.mmt', 
                       [nyg_pars],
                       figshape=(3,2))

# %%
from ionchannelABC.visualization import plot_kde_matrix_custom
import myokit
import numpy as np

# %%
m,_,_ = myokit.load(modelfile)

# %%
originals = {}
for name in limits.keys():
    if name.startswith("log"):
        name_ = name[4:]
    else:
        name_ = name
    val = m.value(name_)
    if name.startswith("log"):
        val_ = np.log10(val)
    else:
        val_ = val
    originals[name] = val_

# %%
sns.set_context('notebook')
g = plot_kde_matrix_custom(df, w, limits=limits, refval=originals)
