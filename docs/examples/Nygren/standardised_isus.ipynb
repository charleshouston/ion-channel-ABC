# %%
import os, tempfile
import logging
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
from ionchannelABC import theoretical_population_size
from ionchannelABC import IonChannelDistance, EfficientMultivariateNormalTransition, IonChannelAcceptor
from ionchannelABC import plot_sim_results, plot_parameters_kde
from ionchannelABC.experiment import setup
# Out:
# INFO:myokit:Loading Myokit version 1.28.3
# /scratch/cph211/miniconda3/envs/ionchannelABC/lib/python3.7/site-packages/ionchannelABC-0.2.0-py3.7.egg/ionchannelABC/visualization.py:290: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# /scratch/cph211/miniconda3/envs/ionchannelABC/lib/python3.7/site-packages/ionchannelABC-0.2.0-py3.7.egg/ionchannelABC/visualization.py:306: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# /scratch/cph211/miniconda3/envs/ionchannelABC/lib/python3.7/site-packages/ionchannelABC-0.2.0-py3.7.egg/ionchannelABC/visualization.py:290: SyntaxWarning: assertion is always true, perhaps remove parentheses?
# /scratch/cph211/miniconda3/envs/ionchannelABC/lib/python3.7/site-packages/ionchannelABC-0.2.0-py3.7.egg/ionchannelABC/visualization.py:306: SyntaxWarning: assertion is always true, perhaps remove parentheses?

# %%
from pyabc import Distribution, RV, History, ABCSMC
from pyabc.epsilon import MedianEpsilon
from pyabc.sampler import MulticoreEvalParallelSampler, SingleCoreSampler
from pyabc.populationstrategy import ConstantPopulationSize

# %%
from experiments.isus_wang import (wang_act_and_kin,
                                   wang_inact)
from experiments.isus_courtemanche import (courtemanche_inact_kin,
                                           courtemanche_deact)
from experiments.isus_firek import (firek_inact)
from experiments.isus_nygren import (nygren_inact_kin,
                                     nygren_rec)

# %%
modelfile = 'models/standardised_isus.mmt'

# %% [markdown]
# ## Plot steady-state and tau functions

# %%
from ionchannelABC.visualization import plot_variables

# %%
sns.set_context('poster')

V = np.arange(-80, 40, 0.01)

sta_vars = {'ri': 'isus.r_ss',
            'si': 'isus.s_ss',
            'rt': 'isus.tau_r',
            'st': 'isus.tau_s'}

f, ax = plot_variables(V, sta_vars, modelfile, figshape=(2,2))

# %% [markdown]
# ## Activation only

# %%
observations, model, summary_statistics = setup(modelfile,
                                                wang_act_and_kin,
                                                courtemanche_deact)
                                                #firek_inact,
                                                #nygren_inact_kin,
                                                #nygren_rec)

# %%
assert len(observations)==len(summary_statistics(model({})))

# %%
g = plot_sim_results(modelfile,
                     wang_act_and_kin,
                    courtemanche_deact)
                    #firek_inact,
                    #nygren_inact_kin,
                    #nygren_rec)

# %%
limits = {'log_isus.p_1': (-7, 3),
          'isus.p_2': (1e-7, 0.4),
          'log_isus.p_3': (-7, 3),
          'isus.p_4': (1e-7, 0.4)}
          #'log_isus.p_5': (-7, 3),
          #'isus.p_6': (1e-7, 0.4),
          #'log_isus.p_7': (-9, 1),
          #'isus.p_8': (1e-7, 0.4)}
prior = Distribution(**{key: RV("uniform", a, b - a)
                        for key, (a,b) in limits.items()})

# %% [markdown]
# ### Run ABC calibration

# %%
db_path = ("sqlite:///" +
            os.path.join(tempfile.gettempdir(), "standardised_isus.db"))

# %%
logging.basicConfig()
abc_logger = logging.getLogger('ABC')
abc_logger.setLevel(logging.DEBUG)
eps_logger = logging.getLogger('Epsilon')
eps_logger.setLevel(logging.DEBUG)

# %%
pop_size = theoretical_population_size(2, len(limits))
print("Theoretical minimum population size is {} particles".format(pop_size))
# Out:
# Theoretical minimum population size is 16 particles

# %%
abc = ABCSMC(models=model,
             parameter_priors=prior,
             distance_function=IonChannelDistance(
                 exp_id=list(observations.exp_id),
                 variance=list(observations.variance),
                 delta=0.05),
             population_size=ConstantPopulationSize(1000),
             summary_statistics=summary_statistics,
             transitions=EfficientMultivariateNormalTransition(),
             eps=MedianEpsilon(initial_epsilon=100),
             sampler=MulticoreEvalParallelSampler(n_procs=16),
             acceptor=IonChannelAcceptor())
# Out:
# DEBUG:ABC:ion channel weights: {'0': 0.9291864600781273, '1': 0.9289966364907764, '2': 1.1348736050966737, '3': 1.1351568985577465, '4': 1.0214372272287315, '5': 0.6011154706704985, '6': 0.8515802501165396, '7': 0.8517397519427469, '8': 0.8517397519427501, '9': 0.8515802501165396, '10': 0.06311509727573296, '11': 0.2414626843624501, '12': 0.29232255580339506, '13': 0.6534268894428844, '14': 0.8550117212573513, '15': 0.7403514554934645, '16': 0.6534268894428801, '17': 0.7929901456221022, '18': 3.0675207501965804, '19': 2.208952913507944, '20': 1.7402522202557973, '21': 1.5337603750982902}
# DEBUG:Epsilon:init quantile_epsilon initial_epsilon=100, quantile_multiplier=1

# %%
obs = observations.to_dict()['y']
obs = {str(k): v for k, v in obs.items()}

# %%
abc_id = abc.new(db_path, obs)
# Out:
# INFO:History:Start <ABCSMC(id=1, start_time=2019-10-29 10:00:19.049244, end_time=None)>

# %%
history = abc.run(minimum_epsilon=0., max_nr_populations=100, min_acceptance_rate=0.01)
# Out:
# INFO:ABC:t:0 eps:100
# DEBUG:ABC:now submitting population 0
# DEBUG:ABC:population 0 done
# DEBUG:ABC:
# total nr simulations up to t =0 is 2088
# DEBUG:Epsilon:new eps, t=1, eps=3.35328826722648
# INFO:ABC:t:1 eps:3.35328826722648
# DEBUG:ABC:now submitting population 1
# DEBUG:ABC:population 1 done
# DEBUG:ABC:
# total nr simulations up to t =1 is 4362
# DEBUG:Epsilon:new eps, t=2, eps=3.0298839205846275
# INFO:ABC:t:2 eps:3.0298839205846275
# DEBUG:ABC:now submitting population 2
# DEBUG:ABC:population 2 done
# DEBUG:ABC:
# total nr simulations up to t =2 is 6759
# DEBUG:Epsilon:new eps, t=3, eps=2.9075994876357454
# INFO:ABC:t:3 eps:2.9075994876357454
# DEBUG:ABC:now submitting population 3
# DEBUG:ABC:population 3 done
# DEBUG:ABC:
# total nr simulations up to t =3 is 9700
# DEBUG:Epsilon:new eps, t=4, eps=2.8389821881583965
# INFO:ABC:t:4 eps:2.8389821881583965
# DEBUG:ABC:now submitting population 4
# DEBUG:ABC:population 4 done
# DEBUG:ABC:
# total nr simulations up to t =4 is 13769
# DEBUG:Epsilon:new eps, t=5, eps=2.6060970684804694
# INFO:ABC:t:5 eps:2.6060970684804694
# DEBUG:ABC:now submitting population 5
# DEBUG:ABC:population 5 done
# DEBUG:ABC:
# total nr simulations up to t =5 is 16498
# DEBUG:Epsilon:new eps, t=6, eps=2.350970503530876
# INFO:ABC:t:6 eps:2.350970503530876
# DEBUG:ABC:now submitting population 6
# DEBUG:ABC:population 6 done
# DEBUG:ABC:
# total nr simulations up to t =6 is 19243
# DEBUG:Epsilon:new eps, t=7, eps=2.0387647462866463
# INFO:ABC:t:7 eps:2.0387647462866463
# DEBUG:ABC:now submitting population 7
# DEBUG:ABC:population 7 done
# DEBUG:ABC:
# total nr simulations up to t =7 is 21878
# DEBUG:Epsilon:new eps, t=8, eps=1.7752170427046652
# INFO:ABC:t:8 eps:1.7752170427046652
# DEBUG:ABC:now submitting population 8
# DEBUG:ABC:population 8 done
# DEBUG:ABC:
# total nr simulations up to t =8 is 24260
# DEBUG:Epsilon:new eps, t=9, eps=1.4657502555880983
# INFO:ABC:t:9 eps:1.4657502555880983
# DEBUG:ABC:now submitting population 9
# DEBUG:ABC:population 9 done
# DEBUG:ABC:
# total nr simulations up to t =9 is 26588
# DEBUG:Epsilon:new eps, t=10, eps=1.2038685389150545
# INFO:ABC:t:10 eps:1.2038685389150545
# DEBUG:ABC:now submitting population 10
# DEBUG:ABC:population 10 done
# DEBUG:ABC:
# total nr simulations up to t =10 is 28889
# DEBUG:Epsilon:new eps, t=11, eps=0.9839272594324429
# INFO:ABC:t:11 eps:0.9839272594324429
# DEBUG:ABC:now submitting population 11
# DEBUG:ABC:population 11 done
# DEBUG:ABC:
# total nr simulations up to t =11 is 31267
# DEBUG:Epsilon:new eps, t=12, eps=0.8149683256205312
# INFO:ABC:t:12 eps:0.8149683256205312
# DEBUG:ABC:now submitting population 12
# DEBUG:ABC:population 12 done
# DEBUG:ABC:
# total nr simulations up to t =12 is 33542
# DEBUG:Epsilon:new eps, t=13, eps=0.6926933637117406
# INFO:ABC:t:13 eps:0.6926933637117406
# DEBUG:ABC:now submitting population 13
# DEBUG:ABC:population 13 done
# DEBUG:ABC:
# total nr simulations up to t =13 is 35828
# DEBUG:Epsilon:new eps, t=14, eps=0.5942867375304506
# INFO:ABC:t:14 eps:0.5942867375304506
# DEBUG:ABC:now submitting population 14
# DEBUG:ABC:population 14 done
# DEBUG:ABC:
# total nr simulations up to t =14 is 38177
# DEBUG:Epsilon:new eps, t=15, eps=0.5294053841260825
# INFO:ABC:t:15 eps:0.5294053841260825
# DEBUG:ABC:now submitting population 15
# DEBUG:ABC:population 15 done
# DEBUG:ABC:
# total nr simulations up to t =15 is 40472
# DEBUG:Epsilon:new eps, t=16, eps=0.48583594790007556
# INFO:ABC:t:16 eps:0.48583594790007556
# DEBUG:ABC:now submitting population 16
# DEBUG:ABC:population 16 done
# DEBUG:ABC:
# total nr simulations up to t =16 is 42758
# DEBUG:Epsilon:new eps, t=17, eps=0.45460212226636393
# INFO:ABC:t:17 eps:0.45460212226636393
# DEBUG:ABC:now submitting population 17
# DEBUG:ABC:population 17 done
# DEBUG:ABC:
# total nr simulations up to t =17 is 45037
# DEBUG:Epsilon:new eps, t=18, eps=0.429330153615378
# INFO:ABC:t:18 eps:0.429330153615378
# DEBUG:ABC:now submitting population 18
# DEBUG:ABC:population 18 done
# DEBUG:ABC:
# total nr simulations up to t =18 is 47312
# DEBUG:Epsilon:new eps, t=19, eps=0.40729510875057273
# INFO:ABC:t:19 eps:0.40729510875057273
# DEBUG:ABC:now submitting population 19
# DEBUG:ABC:population 19 done
# DEBUG:ABC:
# total nr simulations up to t =19 is 49590
# DEBUG:Epsilon:new eps, t=20, eps=0.3921033569567667
# INFO:ABC:t:20 eps:0.3921033569567667
# DEBUG:ABC:now submitting population 20
# DEBUG:ABC:population 20 done
# DEBUG:ABC:
# total nr simulations up to t =20 is 51723
# DEBUG:Epsilon:new eps, t=21, eps=0.38002937368284684
# INFO:ABC:t:21 eps:0.38002937368284684
# DEBUG:ABC:now submitting population 21
# DEBUG:ABC:population 21 done
# DEBUG:ABC:
# total nr simulations up to t =21 is 53975
# DEBUG:Epsilon:new eps, t=22, eps=0.3709254332760634
# INFO:ABC:t:22 eps:0.3709254332760634
# DEBUG:ABC:now submitting population 22
# DEBUG:ABC:population 22 done
# DEBUG:ABC:
# total nr simulations up to t =22 is 56165
# DEBUG:Epsilon:new eps, t=23, eps=0.3639073659679205
# INFO:ABC:t:23 eps:0.3639073659679205
# DEBUG:ABC:now submitting population 23
# DEBUG:ABC:population 23 done
# DEBUG:ABC:
# total nr simulations up to t =23 is 58553
# DEBUG:Epsilon:new eps, t=24, eps=0.3587147673507929
# INFO:ABC:t:24 eps:0.3587147673507929
# DEBUG:ABC:now submitting population 24
# DEBUG:ABC:population 24 done
# DEBUG:ABC:
# total nr simulations up to t =24 is 60780
# DEBUG:Epsilon:new eps, t=25, eps=0.35468868538043885
# INFO:ABC:t:25 eps:0.35468868538043885
# DEBUG:ABC:now submitting population 25
# DEBUG:ABC:population 25 done
# DEBUG:ABC:
# total nr simulations up to t =25 is 63012
# DEBUG:Epsilon:new eps, t=26, eps=0.3518926606000159
# INFO:ABC:t:26 eps:0.3518926606000159
# DEBUG:ABC:now submitting population 26
# DEBUG:ABC:population 26 done
# DEBUG:ABC:
# total nr simulations up to t =26 is 65248
# DEBUG:Epsilon:new eps, t=27, eps=0.3496233428612266
# INFO:ABC:t:27 eps:0.3496233428612266
# DEBUG:ABC:now submitting population 27
# DEBUG:ABC:population 27 done
# DEBUG:ABC:
# total nr simulations up to t =27 is 67581
# DEBUG:Epsilon:new eps, t=28, eps=0.3480262328683119
# INFO:ABC:t:28 eps:0.3480262328683119
# DEBUG:ABC:now submitting population 28
# DEBUG:ABC:population 28 done
# DEBUG:ABC:
# total nr simulations up to t =28 is 69866
# DEBUG:Epsilon:new eps, t=29, eps=0.34699961010149016
# INFO:ABC:t:29 eps:0.34699961010149016
# DEBUG:ABC:now submitting population 29
# DEBUG:ABC:population 29 done
# DEBUG:ABC:
# total nr simulations up to t =29 is 72152
# DEBUG:Epsilon:new eps, t=30, eps=0.34628598406817473
# INFO:ABC:t:30 eps:0.34628598406817473
# DEBUG:ABC:now submitting population 30
# DEBUG:ABC:population 30 done
# DEBUG:ABC:
# total nr simulations up to t =30 is 74477
# DEBUG:Epsilon:new eps, t=31, eps=0.34571444360351733
# INFO:ABC:t:31 eps:0.34571444360351733
# DEBUG:ABC:now submitting population 31
# DEBUG:ABC:population 31 done
# DEBUG:ABC:
# total nr simulations up to t =31 is 76992
# DEBUG:Epsilon:new eps, t=32, eps=0.3453710730526743
# INFO:ABC:t:32 eps:0.3453710730526743
# DEBUG:ABC:now submitting population 32
# DEBUG:ABC:population 32 done
# DEBUG:ABC:
# total nr simulations up to t =32 is 79484
# DEBUG:Epsilon:new eps, t=33, eps=0.34507548762745566
# INFO:ABC:t:33 eps:0.34507548762745566
# DEBUG:ABC:now submitting population 33
# DEBUG:ABC:population 33 done
# DEBUG:ABC:
# total nr simulations up to t =33 is 82283
# DEBUG:Epsilon:new eps, t=34, eps=0.34485225737619424
# INFO:ABC:t:34 eps:0.34485225737619424
# DEBUG:ABC:now submitting population 34
# DEBUG:ABC:population 34 done
# DEBUG:ABC:
# total nr simulations up to t =34 is 85580
# DEBUG:Epsilon:new eps, t=35, eps=0.3446621833401922
# INFO:ABC:t:35 eps:0.3446621833401922
# DEBUG:ABC:now submitting population 35
# DEBUG:ABC:population 35 done
# DEBUG:ABC:
# total nr simulations up to t =35 is 89864
# DEBUG:Epsilon:new eps, t=36, eps=0.3445131342000984
# INFO:ABC:t:36 eps:0.3445131342000984
# DEBUG:ABC:now submitting population 36
# DEBUG:ABC:population 36 done
# DEBUG:ABC:
# total nr simulations up to t =36 is 94885
# DEBUG:Epsilon:new eps, t=37, eps=0.34434598569723807
# INFO:ABC:t:37 eps:0.34434598569723807
# DEBUG:ABC:now submitting population 37
# DEBUG:ABC:population 37 done
# DEBUG:ABC:
# total nr simulations up to t =37 is 106012
# DEBUG:Epsilon:new eps, t=38, eps=0.3442417339495923
# INFO:ABC:t:38 eps:0.3442417339495923
# DEBUG:ABC:now submitting population 38
# DEBUG:ABC:population 38 done
# DEBUG:ABC:
# total nr simulations up to t =38 is 117131
# DEBUG:Epsilon:new eps, t=39, eps=0.34415444445396476
# INFO:ABC:t:39 eps:0.34415444445396476
# DEBUG:ABC:now submitting population 39
# DEBUG:ABC:population 39 done
# DEBUG:ABC:
# total nr simulations up to t =39 is 133548
# DEBUG:Epsilon:new eps, t=40, eps=0.34406175534649563
# INFO:ABC:t:40 eps:0.34406175534649563
# DEBUG:ABC:now submitting population 40
# DEBUG:ABC:population 40 done
# DEBUG:ABC:
# total nr simulations up to t =40 is 175884
# DEBUG:Epsilon:new eps, t=41, eps=0.34392554358094246
# INFO:ABC:t:41 eps:0.34392554358094246
# DEBUG:ABC:now submitting population 41

# %%
history = abc.run(minimum_epsilon=0., max_nr_populations=100, min_acceptance_rate=0.01)

# %% [markdown]
# ### Database results analysis

# %%
history = History(db_path)

# %%
df, w = history.get_distribution(m=0)

# %%
df.describe()
# Out:
# name      isus.p_2     isus.p_4  log_isus.p_1  log_isus.p_3
# count  1000.000000  1000.000000   1000.000000   1000.000000
# mean      0.126862     0.022292     -0.961207     -0.971342
# std       0.001197     0.000122      0.006567      0.002508
# min       0.123505     0.021954     -0.978314     -0.977761
# 25%       0.126321     0.022210     -0.965287     -0.973061
# 50%       0.127072     0.022292     -0.961280     -0.971309
# 75%       0.127361     0.022381     -0.957215     -0.969617
# max       0.131505     0.022635     -0.944591     -0.964917

# %%
g = plot_sim_results(modelfile,
                     wang_act_and_kin,
                     courtemanche_deact,
                     #firek_inact,
                     #nygren_inact_kin,
                     #nygren_rec,
                     df=df, w=w)

# %%
sta_pars = df.sample(n=100, weights=w, replace=True)
sta_pars = sta_pars.set_index([pd.Index(range(100))])
sta_pars = sta_pars.to_dict(orient='records')

# %%
sns.set_context('poster')
mpl.rcParams['font.size'] = 14
mpl.rcParams['legend.fontsize'] = 14

f, ax = plot_variables(V, sta_vars, 
                       modelfile, 
                       [sta_pars],
                       figshape=(2,2))

# %%
from ionchannelABC.visualization import plot_kde_matrix_custom
import myokit
import numpy as np

# %%
m,_,_ = myokit.load(modelfile)

# %%
originals = {}
for name in limits.keys():
    if name.startswith("log"):
        name_ = name[4:]
    else:
        name_ = name
    val = m.value(name_)
    if name.startswith("log"):
        val_ = np.log10(val)
    else:
        val_ = val
    originals[name] = val_

# %%
sns.set_context('notebook')
g = plot_kde_matrix_custom(df, w, limits=limits)

# %% [markdown]
# ## Inactivation only

# %%
observations, model, summary_statistics = setup(modelfile,
                                                #wang_act_and_kin,
                                                #courtemanche_deact)
                                                firek_inact,
                                                nygren_inact_kin,
                                                nygren_rec)

# %%
assert len(observations)==len(summary_statistics(model({})))

# %%
g = plot_sim_results(modelfile,
                     #wang_act_and_kin,
                     #courtemanche_deact)
                     firek_inact,
                     nygren_inact_kin,
                     nygren_rec)

# %%
limits = {#'log_isus.p_1': (-7, 3),
          #'isus.p_2': (1e-7, 0.4),
          #'log_isus.p_3': (-7, 3),
          #'isus.p_4': (1e-7, 0.4)}
          'log_isus.p_5': (-7, 3),
          'isus.p_6': (1e-7, 0.4),
          'log_isus.p_7': (-7, 3),
          'isus.p_8': (1e-7, 0.4)}
prior = Distribution(**{key: RV("uniform", a, b - a)
                        for key, (a,b) in limits.items()})

# %% [markdown]
# ### Run ABC calibration

# %%
db_path = ("sqlite:///" +
            os.path.join(tempfile.gettempdir(), "standardised_isus.db"))

# %%
logging.basicConfig()
abc_logger = logging.getLogger('ABC')
abc_logger.setLevel(logging.DEBUG)
eps_logger = logging.getLogger('Epsilon')
eps_logger.setLevel(logging.DEBUG)

# %%
pop_size = theoretical_population_size(2, len(limits))
print("Theoretical minimum population size is {} particles".format(pop_size))
# Out:
# Theoretical minimum population size is 16 particles

# %%
abc = ABCSMC(models=model,
             parameter_priors=prior,
             distance_function=IonChannelDistance(
                 exp_id=list(observations.exp_id),
                 variance=list(observations.variance),
                 delta=0.05),
             population_size=ConstantPopulationSize(500),
             summary_statistics=summary_statistics,
             transitions=EfficientMultivariateNormalTransition(),
             eps=MedianEpsilon(initial_epsilon=100),
             sampler=MulticoreEvalParallelSampler(n_procs=16),
             acceptor=IonChannelAcceptor())
# Out:
# DEBUG:ABC:ion channel weights: {'0': 0.4248110530506898, '1': 0.9476554260361589, '2': 0.47382771301807824, '3': 0.513313355769584, '4': 0.35198630109914286, '5': 0.6159760269235005, '6': 0.947655426036154, '7': 1.0466865780553765, '8': 1.132484698318266, '9': 0.6459809613606207, '10': 1.0541409114085802, '11': 0.9789135226692829, '12': 0.9906822580908385, '13': 3.875885768163725}
# DEBUG:Epsilon:init quantile_epsilon initial_epsilon=100, quantile_multiplier=1

# %%
obs = observations.to_dict()['y']
obs = {str(k): v for k, v in obs.items()}

# %%
abc_id = abc.new(db_path, obs)
# Out:
# INFO:History:Start <ABCSMC(id=2, start_time=2019-10-29 11:14:55.599672, end_time=None)>

# %%
history = abc.run(minimum_epsilon=0., max_nr_populations=100, min_acceptance_rate=0.01)
# Out:
# INFO:ABC:t:0 eps:100
# DEBUG:ABC:now submitting population 0
# DEBUG:ABC:population 0 done
# DEBUG:ABC:
# total nr simulations up to t =0 is 4169
# DEBUG:Epsilon:new eps, t=1, eps=4.218063245723851
# INFO:ABC:t:1 eps:4.218063245723851
# DEBUG:ABC:now submitting population 1
# DEBUG:ABC:population 1 done
# DEBUG:ABC:
# total nr simulations up to t =1 is 5260
# DEBUG:Epsilon:new eps, t=2, eps=4.062476034218735
# INFO:ABC:t:2 eps:4.062476034218735
# DEBUG:ABC:now submitting population 2
# DEBUG:ABC:population 2 done
# DEBUG:ABC:
# total nr simulations up to t =2 is 6536
# DEBUG:Epsilon:new eps, t=3, eps=3.4425077359908327
# INFO:ABC:t:3 eps:3.4425077359908327
# DEBUG:ABC:now submitting population 3
# DEBUG:ABC:population 3 done
# DEBUG:ABC:
# total nr simulations up to t =3 is 7969
# DEBUG:Epsilon:new eps, t=4, eps=2.589781635129379
# INFO:ABC:t:4 eps:2.589781635129379
# DEBUG:ABC:now submitting population 4
# DEBUG:ABC:population 4 done
# DEBUG:ABC:
# total nr simulations up to t =4 is 9228
# DEBUG:Epsilon:new eps, t=5, eps=2.048785989200525
# INFO:ABC:t:5 eps:2.048785989200525
# DEBUG:ABC:now submitting population 5
# DEBUG:ABC:population 5 done
# DEBUG:ABC:
# total nr simulations up to t =5 is 10771
# DEBUG:Epsilon:new eps, t=6, eps=1.7668299296411198
# INFO:ABC:t:6 eps:1.7668299296411198
# DEBUG:ABC:now submitting population 6
# DEBUG:ABC:population 6 done
# DEBUG:ABC:
# total nr simulations up to t =6 is 13660
# DEBUG:Epsilon:new eps, t=7, eps=1.6971265960307818
# INFO:ABC:t:7 eps:1.6971265960307818
# DEBUG:ABC:now submitting population 7
# DEBUG:ABC:population 7 done
# DEBUG:ABC:
# total nr simulations up to t =7 is 17877
# DEBUG:Epsilon:new eps, t=8, eps=1.6511582663973385
# INFO:ABC:t:8 eps:1.6511582663973385
# DEBUG:ABC:now submitting population 8
# DEBUG:ABC:population 8 done
# DEBUG:ABC:
# total nr simulations up to t =8 is 22812
# DEBUG:Epsilon:new eps, t=9, eps=1.5593765571941192
# INFO:ABC:t:9 eps:1.5593765571941192
# DEBUG:ABC:now submitting population 9
# DEBUG:ABC:population 9 done
# DEBUG:ABC:
# total nr simulations up to t =9 is 27799
# DEBUG:Epsilon:new eps, t=10, eps=1.3030348376357717
# INFO:ABC:t:10 eps:1.3030348376357717
# DEBUG:ABC:now submitting population 10
# DEBUG:ABC:population 10 done
# DEBUG:ABC:
# total nr simulations up to t =10 is 44400
# DEBUG:Epsilon:new eps, t=11, eps=1.1511767515759268
# INFO:ABC:t:11 eps:1.1511767515759268
# DEBUG:ABC:now submitting population 11
# DEBUG:ABC:population 11 done
# DEBUG:ABC:
# total nr simulations up to t =11 is 50026
# DEBUG:Epsilon:new eps, t=12, eps=0.9824354085809855
# INFO:ABC:t:12 eps:0.9824354085809855
# DEBUG:ABC:now submitting population 12
# DEBUG:ABC:population 12 done
# DEBUG:ABC:
# total nr simulations up to t =12 is 57055
# DEBUG:Epsilon:new eps, t=13, eps=0.8349845153295302
# INFO:ABC:t:13 eps:0.8349845153295302
# DEBUG:ABC:now submitting population 13
# DEBUG:ABC:population 13 done
# DEBUG:ABC:
# total nr simulations up to t =13 is 62924
# DEBUG:Epsilon:new eps, t=14, eps=0.7138987368638849
# INFO:ABC:t:14 eps:0.7138987368638849
# DEBUG:ABC:now submitting population 14
# DEBUG:ABC:population 14 done
# DEBUG:ABC:
# total nr simulations up to t =14 is 67017
# DEBUG:Epsilon:new eps, t=15, eps=0.6064033284806265
# INFO:ABC:t:15 eps:0.6064033284806265
# DEBUG:ABC:now submitting population 15
# DEBUG:ABC:population 15 done
# DEBUG:ABC:
# total nr simulations up to t =15 is 70633
# DEBUG:Epsilon:new eps, t=16, eps=0.5154833832129152
# INFO:ABC:t:16 eps:0.5154833832129152
# DEBUG:ABC:now submitting population 16
# DEBUG:ABC:population 16 done
# DEBUG:ABC:
# total nr simulations up to t =16 is 73065
# DEBUG:Epsilon:new eps, t=17, eps=0.45510931265430393
# INFO:ABC:t:17 eps:0.45510931265430393
# DEBUG:ABC:now submitting population 17
# DEBUG:ABC:population 17 done
# DEBUG:ABC:
# total nr simulations up to t =17 is 75332
# DEBUG:Epsilon:new eps, t=18, eps=0.4084982722283209
# INFO:ABC:t:18 eps:0.4084982722283209
# DEBUG:ABC:now submitting population 18
# DEBUG:ABC:population 18 done
# DEBUG:ABC:
# total nr simulations up to t =18 is 77279
# DEBUG:Epsilon:new eps, t=19, eps=0.37491770675484487
# INFO:ABC:t:19 eps:0.37491770675484487
# DEBUG:ABC:now submitting population 19
# DEBUG:ABC:population 19 done
# DEBUG:ABC:
# total nr simulations up to t =19 is 79098
# DEBUG:Epsilon:new eps, t=20, eps=0.3507632974272954
# INFO:ABC:t:20 eps:0.3507632974272954
# DEBUG:ABC:now submitting population 20
# DEBUG:ABC:population 20 done
# DEBUG:ABC:
# total nr simulations up to t =20 is 80865
# DEBUG:Epsilon:new eps, t=21, eps=0.3289617025271392
# INFO:ABC:t:21 eps:0.3289617025271392
# DEBUG:ABC:now submitting population 21
# DEBUG:ABC:population 21 done
# DEBUG:ABC:
# total nr simulations up to t =21 is 83144
# DEBUG:Epsilon:new eps, t=22, eps=0.3160273047349145
# INFO:ABC:t:22 eps:0.3160273047349145
# DEBUG:ABC:now submitting population 22
# DEBUG:ABC:population 22 done
# DEBUG:ABC:
# total nr simulations up to t =22 is 85285
# DEBUG:Epsilon:new eps, t=23, eps=0.30719098601495953
# INFO:ABC:t:23 eps:0.30719098601495953
# DEBUG:ABC:now submitting population 23
# DEBUG:ABC:population 23 done
# DEBUG:ABC:
# total nr simulations up to t =23 is 87777
# DEBUG:Epsilon:new eps, t=24, eps=0.30113502328722214
# INFO:ABC:t:24 eps:0.30113502328722214
# DEBUG:ABC:now submitting population 24
# DEBUG:ABC:population 24 done
# DEBUG:ABC:
# total nr simulations up to t =24 is 90619
# DEBUG:Epsilon:new eps, t=25, eps=0.29524259061539104
# INFO:ABC:t:25 eps:0.29524259061539104
# DEBUG:ABC:now submitting population 25
# DEBUG:ABC:population 25 done
# DEBUG:ABC:
# total nr simulations up to t =25 is 94245
# DEBUG:Epsilon:new eps, t=26, eps=0.2903122375131143
# INFO:ABC:t:26 eps:0.2903122375131143
# DEBUG:ABC:now submitting population 26
# DEBUG:ABC:population 26 done
# DEBUG:ABC:
# total nr simulations up to t =26 is 98576
# DEBUG:Epsilon:new eps, t=27, eps=0.2855034786314025
# INFO:ABC:t:27 eps:0.2855034786314025
# DEBUG:ABC:now submitting population 27
# DEBUG:ABC:population 27 done
# DEBUG:ABC:
# total nr simulations up to t =27 is 101988
# DEBUG:Epsilon:new eps, t=28, eps=0.282085355934913
# INFO:ABC:t:28 eps:0.282085355934913
# DEBUG:ABC:now submitting population 28
# DEBUG:ABC:population 28 done
# DEBUG:ABC:
# total nr simulations up to t =28 is 106486
# DEBUG:Epsilon:new eps, t=29, eps=0.2794345230087592
# INFO:ABC:t:29 eps:0.2794345230087592
# DEBUG:ABC:now submitting population 29
# DEBUG:ABC:population 29 done
# DEBUG:ABC:
# total nr simulations up to t =29 is 109484
# DEBUG:Epsilon:new eps, t=30, eps=0.2772511430389076
# INFO:ABC:t:30 eps:0.2772511430389076
# DEBUG:ABC:now submitting population 30
# DEBUG:ABC:population 30 done
# DEBUG:ABC:
# total nr simulations up to t =30 is 111509
# DEBUG:Epsilon:new eps, t=31, eps=0.27538935568462686
# INFO:ABC:t:31 eps:0.27538935568462686
# DEBUG:ABC:now submitting population 31
# DEBUG:ABC:population 31 done
# DEBUG:ABC:
# total nr simulations up to t =31 is 113223
# DEBUG:Epsilon:new eps, t=32, eps=0.27409477868964466
# INFO:ABC:t:32 eps:0.27409477868964466
# DEBUG:ABC:now submitting population 32
# DEBUG:ABC:population 32 done
# DEBUG:ABC:
# total nr simulations up to t =32 is 114655
# DEBUG:Epsilon:new eps, t=33, eps=0.27323559247473644
# INFO:ABC:t:33 eps:0.27323559247473644
# DEBUG:ABC:now submitting population 33
# DEBUG:ABC:population 33 done
# DEBUG:ABC:
# total nr simulations up to t =33 is 116034
# DEBUG:Epsilon:new eps, t=34, eps=0.2726619764867795
# INFO:ABC:t:34 eps:0.2726619764867795
# DEBUG:ABC:now submitting population 34
# DEBUG:ABC:population 34 done
# DEBUG:ABC:
# total nr simulations up to t =34 is 117686
# DEBUG:Epsilon:new eps, t=35, eps=0.272083224293716
# INFO:ABC:t:35 eps:0.272083224293716
# DEBUG:ABC:now submitting population 35
# DEBUG:ABC:population 35 done
# DEBUG:ABC:
# total nr simulations up to t =35 is 119410
# DEBUG:Epsilon:new eps, t=36, eps=0.27171807033581713
# INFO:ABC:t:36 eps:0.27171807033581713
# DEBUG:ABC:now submitting population 36
# DEBUG:ABC:population 36 done
# DEBUG:ABC:
# total nr simulations up to t =36 is 121054
# DEBUG:Epsilon:new eps, t=37, eps=0.271455602641544
# INFO:ABC:t:37 eps:0.271455602641544
# DEBUG:ABC:now submitting population 37
# DEBUG:ABC:population 37 done
# DEBUG:ABC:
# total nr simulations up to t =37 is 122518
# DEBUG:Epsilon:new eps, t=38, eps=0.2712615906088829
# INFO:ABC:t:38 eps:0.2712615906088829
# DEBUG:ABC:now submitting population 38
# DEBUG:ABC:population 38 done
# DEBUG:ABC:
# total nr simulations up to t =38 is 123869
# DEBUG:Epsilon:new eps, t=39, eps=0.27113942984992895
# INFO:ABC:t:39 eps:0.27113942984992895
# DEBUG:ABC:now submitting population 39
# DEBUG:ABC:population 39 done
# DEBUG:ABC:
# total nr simulations up to t =39 is 125192
# DEBUG:Epsilon:new eps, t=40, eps=0.27106296834254207
# INFO:ABC:t:40 eps:0.27106296834254207
# DEBUG:ABC:now submitting population 40
# DEBUG:ABC:population 40 done
# DEBUG:ABC:
# total nr simulations up to t =40 is 126423
# DEBUG:Epsilon:new eps, t=41, eps=0.27101068929244926
# INFO:ABC:t:41 eps:0.27101068929244926
# DEBUG:ABC:now submitting population 41
# DEBUG:ABC:population 41 done
# DEBUG:ABC:
# total nr simulations up to t =41 is 127614
# DEBUG:Epsilon:new eps, t=42, eps=0.27097292786457616
# INFO:ABC:t:42 eps:0.27097292786457616
# DEBUG:ABC:now submitting population 42
# DEBUG:ABC:population 42 done
# DEBUG:ABC:
# total nr simulations up to t =42 is 128973
# DEBUG:Epsilon:new eps, t=43, eps=0.2709478117420186
# INFO:ABC:t:43 eps:0.2709478117420186
# DEBUG:ABC:now submitting population 43
# DEBUG:ABC:population 43 done
# DEBUG:ABC:
# total nr simulations up to t =43 is 130563
# DEBUG:Epsilon:new eps, t=44, eps=0.27093180429927344
# INFO:ABC:t:44 eps:0.27093180429927344
# DEBUG:ABC:now submitting population 44
# DEBUG:ABC:population 44 done
# DEBUG:ABC:
# total nr simulations up to t =44 is 131994
# DEBUG:Epsilon:new eps, t=45, eps=0.27091909785445356
# INFO:ABC:t:45 eps:0.27091909785445356
# DEBUG:ABC:now submitting population 45
# DEBUG:ABC:population 45 done
# DEBUG:ABC:
# total nr simulations up to t =45 is 133823
# DEBUG:Epsilon:new eps, t=46, eps=0.2709087484757765
# INFO:ABC:t:46 eps:0.2709087484757765
# DEBUG:ABC:now submitting population 46
# DEBUG:ABC:population 46 done
# DEBUG:ABC:
# total nr simulations up to t =46 is 136625
# DEBUG:Epsilon:new eps, t=47, eps=0.27090240934879384
# INFO:ABC:t:47 eps:0.27090240934879384
# DEBUG:ABC:now submitting population 47
# DEBUG:ABC:population 47 done
# DEBUG:ABC:
# total nr simulations up to t =47 is 138851
# DEBUG:Epsilon:new eps, t=48, eps=0.27089709465957873
# INFO:ABC:t:48 eps:0.27089709465957873
# DEBUG:ABC:now submitting population 48
# DEBUG:ABC:population 48 done
# DEBUG:ABC:
# total nr simulations up to t =48 is 142352
# DEBUG:Epsilon:new eps, t=49, eps=0.27089299425196767
# INFO:ABC:t:49 eps:0.27089299425196767
# DEBUG:ABC:now submitting population 49
# DEBUG:ABC:population 49 done
# DEBUG:ABC:
# total nr simulations up to t =49 is 145955
# DEBUG:Epsilon:new eps, t=50, eps=0.27089051070144887
# INFO:ABC:t:50 eps:0.27089051070144887
# DEBUG:ABC:now submitting population 50
# DEBUG:ABC:population 50 done
# DEBUG:ABC:
# total nr simulations up to t =50 is 149429
# DEBUG:Epsilon:new eps, t=51, eps=0.2708889303171497
# INFO:ABC:t:51 eps:0.2708889303171497
# DEBUG:ABC:now submitting population 51
# DEBUG:ABC:population 51 done
# DEBUG:ABC:
# total nr simulations up to t =51 is 154585
# DEBUG:Epsilon:new eps, t=52, eps=0.27088680468909804
# INFO:ABC:t:52 eps:0.27088680468909804
# DEBUG:ABC:now submitting population 52
# DEBUG:ABC:population 52 done

# %% [markdown]
# ### Database results analysis

# %%
history = History(db_path)

# %%
df, w = history.get_distribution(m=0)

# %%
df.describe()
# Out:
# name     isus.p_6    isus.p_8  log_isus.p_5  log_isus.p_7
# count  500.000000  500.000000    500.000000    500.000000
# mean     0.001549    0.028790     -2.357002     -5.858582
# std      0.000004    0.000038      0.000107      0.003925
# min      0.001533    0.028709     -2.357409     -5.874776
# 25%      0.001547    0.028767     -2.357060     -5.858205
# 50%      0.001549    0.028783     -2.357001     -5.857286
# 75%      0.001551    0.028802     -2.356936     -5.856556
# max      0.001561    0.028980     -2.356598     -5.855090

# %%
g = plot_sim_results(modelfile,
                     #wang_act_and_kin,
                     #courtemanche_deact,
                     firek_inact,
                     nygren_inact_kin,
                     nygren_rec,
                     df=df, w=w)

# %%
sta_pars = df.sample(n=100, weights=w, replace=True)
sta_pars = sta_pars.set_index([pd.Index(range(100))])
sta_pars = sta_pars.to_dict(orient='records')

# %%
sns.set_context('poster')
mpl.rcParams['font.size'] = 14
mpl.rcParams['legend.fontsize'] = 14

f, ax = plot_variables(V, sta_vars, 
                       modelfile, 
                       [sta_pars],
                       figshape=(2,2))

# %%
from ionchannelABC.visualization import plot_kde_matrix_custom
import myokit
import numpy as np

# %%
m,_,_ = myokit.load(modelfile)

# %%
originals = {}
for name in limits.keys():
    if name.startswith("log"):
        name_ = name[4:]
    else:
        name_ = name
    val = m.value(name_)
    if name.startswith("log"):
        val_ = np.log10(val)
    else:
        val_ = val
    originals[name] = val_

# %%
sns.set_context('notebook')
g = plot_kde_matrix_custom(df, w, limits=limits)

# %% [markdown]
# ## Full calibration

# %%
observations, model, summary_statistics = setup(modelfile,
                                                wang_act_and_kin,
                                                courtemanche_deact,
                                                firek_inact,
                                                nygren_inact_kin,
                                                nygren_rec)

# %%
assert len(observations)==len(summary_statistics(model({})))

# %%
g = plot_sim_results(modelfile,
                     wang_act_and_kin,
                     courtemanche_deact,
                     firek_inact,
                     nygren_inact_kin,
                     nygren_rec)

# %%
limits = {'log_isus.p_1': (-7, 3),
          'isus.p_2': (1e-7, 0.4),
          'log_isus.p_3': (-7, 3),
          'isus.p_4': (1e-7, 0.4),
          'log_isus.p_5': (-7, 3),
          'isus.p_6': (1e-7, 0.4),
          'log_isus.p_7': (-7, 3),
          'isus.p_8': (1e-7, 0.4)}
prior = Distribution(**{key: RV("uniform", a, b - a)
                        for key, (a,b) in limits.items()})

# %% [markdown]
# ### Run ABC calibration

# %%
db_path = ("sqlite:///" +
            os.path.join(tempfile.gettempdir(), "standardised_isus.db"))

# %%
logging.basicConfig()
abc_logger = logging.getLogger('ABC')
abc_logger.setLevel(logging.DEBUG)
eps_logger = logging.getLogger('Epsilon')
eps_logger.setLevel(logging.DEBUG)

# %%
pop_size = theoretical_population_size(2, len(limits))
print("Theoretical minimum population size is {} particles".format(pop_size))
# Out:
# Theoretical minimum population size is 256 particles

# %%
abc = ABCSMC(models=model,
             parameter_priors=prior,
             distance_function=IonChannelDistance(
                 exp_id=list(observations.exp_id),
                 variance=list(observations.variance),
                 delta=0.05),
             population_size=ConstantPopulationSize(1000),
             summary_statistics=summary_statistics,
             transitions=EfficientMultivariateNormalTransition(),
             eps=MedianEpsilon(initial_epsilon=100),
             sampler=MulticoreEvalParallelSampler(n_procs=16),
             acceptor=IonChannelAcceptor())
# Out:
# DEBUG:ABC:ion channel weights: {'0': 0.757484747137524, '1': 0.7573300005088944, '2': 0.9251635519069269, '3': 0.9253944963781887, '4': 0.8326887584211609, '5': 0.490037059152811, '6': 0.6942191671331489, '7': 0.6943491950723016, '8': 0.6943491950723043, '9': 0.6942191671331489, '10': 0.0514522386566513, '11': 0.19684348434442256, '12': 0.23830510535712207, '13': 0.5326820002100388, '14': 0.6970165465194014, '15': 0.6035440238875321, '16': 0.5326820002100352, '17': 0.6464557607615167, '18': 2.5006823491663805, '19': 1.800766811632805, '20': 1.4186759812504586, '21': 1.2503411745831903, '22': 0.5481676012334781, '23': 1.2228354181362266, '24': 0.6114177090681118, '25': 0.6623691848237867, '26': 0.454196012450596, '27': 0.7948430217885437, '28': 1.2228354181362204, '29': 1.3506232161700145, '30': 1.4613353773463804, '31': 0.83356078305546, '32': 1.3602421373437368, '33': 1.2631702345856923, '34': 1.2783563730330265, '35': 5.001364698332761}
# DEBUG:Epsilon:init quantile_epsilon initial_epsilon=100, quantile_multiplier=1

# %%
obs = observations.to_dict()['y']
obs = {str(k): v for k, v in obs.items()}

# %%
abc_id = abc.new(db_path, obs)
# Out:
# INFO:History:Start <ABCSMC(id=4, start_time=2019-10-30 09:51:20.693959, end_time=None)>

# %%
history = abc.run(minimum_epsilon=0., max_nr_populations=100, min_acceptance_rate=0.01)
# Out:
# INFO:ABC:t:0 eps:100
# DEBUG:ABC:now submitting population 0

# %%
history = abc.run(minimum_epsilon=0., max_nr_populations=100, min_acceptance_rate=0.01)

# %% [markdown]
# ### Database results analysis

# %%
history = History(db_path)

# %%
df, w = history.get_distribution(m=0)

# %%
df.describe()
# Out:
# name      isus.p_2     isus.p_4     isus.p_6     isus.p_8  log_isus.p_1  \
# count  1000.000000  1000.000000  1000.000000  1000.000000   1000.000000
# mean      0.148526     0.020202     0.001559     0.027597     -1.261242
# std       0.012002     0.000898     0.000183     0.002007      0.051327
# min       0.120513     0.017286     0.000954     0.021316     -1.381498
# 25%       0.139339     0.019553     0.001431     0.026243     -1.300054
# 50%       0.147152     0.020160     0.001566     0.027664     -1.258827
# 75%       0.156713     0.020825     0.001678     0.028971     -1.220041
# max       0.192503     0.023309     0.002087     0.034171     -1.122041
#
# name   log_isus.p_3  log_isus.p_5  log_isus.p_7
# count   1000.000000   1000.000000   1000.000000
# mean      -0.924747     -2.352085     -6.820690
# std        0.019491      0.006502      0.160979
# min       -0.991677     -2.370927     -6.999985
# 25%       -0.938004     -2.356456     -6.934211
# 50%       -0.924096     -2.351961     -6.860678
# 75%       -0.910935     -2.347869     -6.756314
# max       -0.860656     -2.330519     -5.943701

# %%
g = plot_sim_results(modelfile,
                     wang_act_and_kin,
                     courtemanche_deact,
                     firek_inact,
                     nygren_inact_kin,
                     nygren_rec,
                     df=df, w=w)

# %%
sta_pars = df.sample(n=100, weights=w, replace=True)
sta_pars = sta_pars.set_index([pd.Index(range(100))])
sta_pars = sta_pars.to_dict(orient='records')

# %%
sns.set_context('poster')
mpl.rcParams['font.size'] = 14
mpl.rcParams['legend.fontsize'] = 14

f, ax = plot_variables(V, sta_vars, 
                       modelfile, 
                       [sta_pars],
                       figshape=(2,2))

# %%
from ionchannelABC.visualization import plot_kde_matrix_custom
import myokit
import numpy as np

# %%
m,_,_ = myokit.load(modelfile)

# %%
originals = {}
for name in limits.keys():
    if name.startswith("log"):
        name_ = name[4:]
    else:
        name_ = name
    val = m.value(name_)
    if name.startswith("log"):
        val_ = np.log10(val)
    else:
        val_ = val
    originals[name] = val_

# %%
sns.set_context('notebook')
g = plot_kde_matrix_custom(df, w, limits=limits)
